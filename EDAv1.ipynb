# %%
import pandas as pd
import sweetviz as sv

cric = pd.read_excel('C:/Users/archi/Final_Cricketer Outputv6.xlsx')
cric
# Out:
#       Unnamed: 0         Player Country/Teams TESTbatting_Span  \
# 0              0  SR Tendulkar          INDIA        1989-2013
# 1              1    RT Ponting            AUS        1995-2012
# 2              2     JH Kallis             SA        1995-2013
# 3              3      R Dravid          INDIA        1996-2012
# 4              4       AN Cook            ENG        2006-2018
# ...          ...            ...           ...              ...
# 5768        5768    Zamir Khan            AFG                0
# 5769        5769      S Zargar            Mex                0
# 5770        5770   Zeshan Arif            Aut                0
# 5771        5771  Ziaur Rahman            AFG                0
# 5772        5772   Zoheb Malek            MLT                0
#
#       TESTbatting_Matches  TESTbatting_Innings  TESTbatting_Not-Outs  \
# 0                     200                  329                    33
# ...

# %%
cric['TESTbatting_Span'] = cric['TESTbatting_Span'].astype(str)
cric['Testbowling_Span'] = cric['Testbowling_Span'].astype(str)
cric['Testbowling_bestbowlingInnings'] = cric['Testbowling_bestbowlingInnings'].astype(str)
cric['Testbowling_bestbowlingMatch'] = cric['Testbowling_bestbowlingMatch'].astype(str)
cric['ODIbatting_Span'] = cric['ODIbatting_Span'].astype(str)
cric['ODIbowling_Span'] = cric['ODIbowling_Span'].astype(str)
cric['ODIbowling_bestbowling'] = cric['ODIbowling_bestbowling'].astype(str)
cric['T20batting_Span'] = cric['T20batting_Span'].astype(str)
cric['T20bowling_Span'] = cric['T20bowling_Span'].astype(str)
cric['T20bowlin_bestbowling'] = cric['T20bowlin_bestbowling'].astype(str)

report = sv.analyze(cric)
report.show_html()
# Out:
#                                              |                                             | [  0%]   00:00 ->…
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
